# %% [markdown]
# ### Python Notebook for testing changes locally
#
# This notebook can be used as a playground to do any quick check of the implementation or approach and verify quick utility functions

# %%
# import the required packages
import boto3

# %%
aws_profile = "hackathon"
session = boto3.session.Session(profile_name=aws_profile)
s3_client = session.client("s3")

# %%
ieee_s3_bucket = "ieee-dataport"
object_key = "competition/1253487/13083/Videos/2024-05-14/Ayyappa_Temple_FIX_1_time_2024-05-14T07/30/02_000.mp4"

# %%
response = s3_client.list_objects_v2(Bucket=ieee_s3_bucket, Prefix=object_key)

# %%
response.get("KeyCount")
# Out:
# 0

# %%
response[("Contents")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response[("Contents")]
#
# KeyError: 'Contents'
