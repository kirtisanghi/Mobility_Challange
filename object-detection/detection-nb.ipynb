# %% [markdown]
# # Object Detection Inference Guide (notebook)

# %% [markdown]
# ### Python package installation

# %% [markdown]
# Install all the required packages

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Ultralytics Package Built and Installation

# %% [markdown]
# Clone the ultralytics git repository. It can be cloned in any temp location

# %%
# !git clone https://github.com/ultralytics/ultralytics

# %% [markdown]
# Navigate to ultralytics folder

# %%
# %cd ultralytics

# %% [markdown]
# Git reset to commit `2071776a3672eb835d7c56cfff22114707765ac`

# %%
# !git reset --hard 2071776a3672eb835d7c56cfff22114707765ac

# %% [markdown]
# Download and apply the patch

# %%
# !wget https://gist.githubusercontent.com/Y-T-G/8f4fc0b78a0a559a06fe84ae4f359e6e/raw/17b1407fefeac86d089c4cf14f174c8bb44948af/add_head.patch

# %%
# !git apply add_head.patch

# %% [markdown]
# Build and install the `ultralytics` package

# %%
# !pip install -e .

# %% [markdown]
# ### Execute Object Detection Inference

# %% [markdown]
# Navigate to the object-detection folder within **Mobility_Challenge**

# %%
# %cd Mobility_Challange/object-detection/

# %% [markdown]
# Run the inference by executing app.py script

# %%
VIDEO_PATH="videos/Stn_HD_1_time_2024-05-14T07:30:02_001.mp4"
OUTPUT_PATH="Output_Turning_Patterns.csv"

# %%
# !python app.py {VIDEO_PATH} {OUTPUT_PATH}
